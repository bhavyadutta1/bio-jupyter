# %% [markdown]
# # <center> <font color=285238> Lab Report </font> </center>
#
# #### <center> BE- Bioprocess Engineering (Fensterle/ Lucassen) </center>
#
# # <center> <font color=285238> Chemostat </font> </center>
#
# ## <font color=E07A5F> Materials and Methods </font>
#
# ### <font color=8AAA79> Equipment set-up </font>
#
# The following pictures depict the equipment set-up.

# %% [markdown]
# ![Screenshot%202022-12-24%20at%2021.11.06.png](attachment:Screenshot%202022-12-24%20at%2021.11.06.png)

# %% [markdown]
# *Figure 1: Assembly of the continuous fermentation. All elements, with the exception of the air-in tube upstream of the sterile filter, needs to be sterilized before running the experiment.*

# %% [markdown]
# ![Screenshot%202022-12-24%20at%2021.11.57.png](attachment:Screenshot%202022-12-24%20at%2021.11.57.png)

# %% [markdown]
# *Figure 2: Assembly for calibration.*

# %% [markdown]
# ![Screenshot%202022-12-24%20at%2021.12.57.png](attachment:Screenshot%202022-12-24%20at%2021.12.57.png)

# %% [markdown]
# *Figure 3: Assembly for sterilization. All tube ends must be wrapped in alu-foil. If bottles wrapped with alu-foil are used for collection: sterilize tubing separately (wrap ends and in addition complete tubing in alu-foil).*

# %% [markdown]
# ### <font color=8AAA79> Media </font>
#
# 1. YPD Medium w/o glucose (final concentrations):
# -  2% Peptone
# -  1% Yeast extract
# -  Sterilize by autoclaving
#
# 2. Glucose:
# -  20% glucose in water
# -  Prepare and sterilize by autoclaving
#
# *Remark: a standard YPD medium contains 2% glucose.*

# %% [markdown]
# ### <font color=8AAA79> Methods </font>
# See lab course BE Applied Microbiology, part methods.

# %% [markdown]
# ## *Day 0: set-up*
# ### <font color=8AAA79> Media preparation and set-up of the bioreactors </font>
#
# Media and glucose has to be autoclaved separately. Therefore prepare the YPD medium w/o glucose encompassing the solid components adjusted to the final volume.
#
# For each bioreactor:
# 1. Bioreactor: X ml YPD medium w/o glc + Y ml glc 20% = 500 ml YPD medium with 2 g/L glc.
# 2. Feed medium: X ml YPD medium w/o glc + Y ml glc 20% = (500 / 800 / 1000 / 2000) ml YPD medium with 30 g/L glc.
# 3. Glucose 20%: Sufficient for bioreactor and feed medium.
#
# Once per lab course: for inoculation, 1 l YPD medium with 20 g/L glucose (can be autoclaved together in this case).
#
# For agar plates, media / PBS required for dilution, please adhere to the supervisors.

# %% [markdown]
# ### <font color=8AAA79> Assembly and calibration </font>
#
# The assembly of the devices will be explained in detail by the supervisors; see figures in the materials and methods section.
#
# **Note: ALL in and out tubings must be closed by hose clamps for autoclaving.**
#
# **Remember: You can close more than one tube with one clamp. Before autoclaving, the assembly must be released by a supervisor!**
#
# The diameter of tubings to be used will be announced by the supervisors. Please note, that the tubing part within the peristaltic pumps must consist of the tubes with small diameter!
#
# For calibration of the peristaltic pumps, the medium in and medium out tubing must be fully assembled. Calibration is performed non-sterile before autoclaving using water. It is your responsibility to note the pump settings required for your dilution rate.

# %% [markdown]
# ### <font color=8AAA79> Final assembly and start of the fermentation </font>
#
# ### <font color=3D0814> Media preparation, inoculation </font>
#
# Outside of the waterbath, add the required amount of glucose 20% to end up with 2 g/L glucose using peristaltic pumps.
#
# Inoculate the bioreactor using peristaltic pumps to reach a final cell concentration of 5x10^6 cells/ml.

# %% [markdown]
# ### <font color=3D0814> Start of fermentation </font>
#
# Place the bioreactor in the waterbath (30°C, stirrer speed 300 rpm).
#
# Fix the aeration. Connect the product-out tubing with the peristaltic pump and the product collection bottle.
# Take first sample.
#
# Continue sampling, until glucose concentration reaches 0 g / L.
#
# **In parallel, prepare and connect the feed medium.**

# %% [markdown]
# ### <font color=3D0814> Start of chemostat operation </font>
#
# As soon as the glucose concentration reaches 0 g / L, start the chemostat operation by starting the feed and product pump with the rate corresponding to your dilution rate. Continue sampling.

# %% [markdown]
# ### <font color=3D0814> Sampling </font>
#
# Sampling is performed in 30 minutes intervals.
#
# The sampling scheme is depicted in Table 3.
#
# For each sampling point, take 1.5 ml product. If also biomass is assessed at this timepoint, take 3.5 ml more. If also an HPLC sample is processed, take 1.5 ml more.
#
#
# Please note the following: “glucose” will be measured using glucose test sticks, glucose measured every one h, CFU and Biomass three measurements in the first day and twice in the second day.
#
# HPLC depicts the samples, which are subsequently analysed by HPLC for glucose and EtOH. These samples are taken hourly on sample per bioreactor.

# %% [markdown]
# -> Insert table

# %% [markdown]
# Table 3: sampling scheme for steady state groups
